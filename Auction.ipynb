# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('auction.csv') 
df.head()
# Out:
#    Unnamed: 0       Country                Player  \
# 0           0        Guyana  Christopher Barnwell
# 1           1  South Africa           Johan Botha
# 2           2     Australia      Daniel Christian
# 3           3     Australia        Michael Clarke
# 4           4     Australia   Nathan Coulter-Nile
#
#                           Team  Base price Winning bid  Year
# 0  Royal Challengers Bangalore        30.5        30.5  2013
# 1             Delhi Daredevils       183.0       274.5  2013
# 2  Royal Challengers Bangalore        61.0        61.0  2013
# 3          Pune Warriors India       244.0       244.0  2013
# 4               Mumbai Indians        61.0       274.5  2013

# %%
# Out:
# Rows & Columns: (1052, 7)
#
# Column Names: ['Unnamed: 0', 'Country', 'Player', 'Team', 'Base price', 'Winning bid', 'Year']

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0     0
# Country        0
# Player         0
# Team           0
# Base price     0
# Winning bid    0
# Year           0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'Country', 'Player', 'Team', 'Base price', 'Winning bid', 'Year']

# %%
df['team'] = df['Team'].replace({
    'Delhi Dardevils': 'Delhi Capitals',     
    'Kings XI Punjab': 'Punjab Kings',        
    'Royal Challengers Bangalore': 'Royal Challengers Bengaluru'
})

# %%
print(df['Team'].unique())
# Out:
# ['Royal Challengers Bangalore' 'Delhi Capitals' 'Pune Warriors India'
#  'Mumbai Indians' 'Chennai Super Kings' 'Sunrisers Hyderabad'
#  'Rajasthan Royals' 'Kings XI Punjab' 'Kolkata Knight Riders'
#  'Delhi Dardevils' 'Rising Pune Supergiants' 'Gujarat Lions'
#  'Punjab Kings' 'Gujarat Titans' 'Lucknow Super Giants']

# %%
df['Team'] = df['Team'].replace({
    'Delhi Dardevils': 'Delhi Capitals',
    'Kings XI Punjab': 'Punjab Kings'
})

# %%
print(df['Team'].unique())
# Out:
# ['Royal Challengers Bangalore' 'Delhi Capitals' 'Pune Warriors India'
#  'Mumbai Indians' 'Chennai Super Kings' 'Sunrisers Hyderabad'
#  'Rajasthan Royals' 'Punjab Kings' 'Kolkata Knight Riders'
#  'Rising Pune Supergiants' 'Gujarat Lions' 'Gujarat Titans'
#  'Lucknow Super Giants']

# %%
df.to_csv('IPLauction.csv', index=False)
print("Fixed and saved!")
# Out:
# Fixed and saved!

# %%
import os
print(os.getcwd())
# Out:
# /Users/divyaseth
